# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sergiopaniego/samples/blob/main/smolagents_vllm_gemma3.ipynb)

# %%
# !pip install -q -U smolagents vllm

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, VLLMModel

# Import search tool
search_tool = DuckDuckGoSearchTool()

# Load model
model_name = "google/gemma-3-4b-it"
model = VLLMModel(model_id=model_name)

# Initialize the agent with search_tool
agent = CodeAgent(tools=[search_tool], model=model)

# Run it!
result = agent.run("How did Real Madrid do in their last La Liga match?")
result
# Out:
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# INFO 04-02 15:59:25 [config.py:585] This model supports multiple tasks: {'score', 'generate', 'classify', 'embed', 'reward'}. Defaulting to 'generate'.
# INFO 04-02 15:59:25 [config.py:1697] Chunked prefill is enabled with max_num_batched_tokens=8192.
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# INFO 04-02 15:59:30 [core.py:54] Initializing a V1 LLM engine (v0.8.2) with config: model='google/gemma-3-4b-it', speculative_config=None, tokenizer='google/gemma-3-4b-it', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=65536, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=None, served_model_name=google/gemma-3-4b-it, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"custom_ops":["none"],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}
# WARNING 04-02 15:59:31 [utils.py:2321] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x7ea95161f010>
# INFO 04-02 15:59:32 [parallel_state.py:954] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 04-02 15:59:32 [cuda.py:220] Using Flash Attention backend on V1 engine.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# INFO 04-02 15:59:43 [gpu_model_runner.py:1174] Starting to load model google/gemma-3-4b-it...
# INFO 04-02 15:59:43 [config.py:3243] cudagraph sizes specified by model runner [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 264, 272, 280, 288, 296, 304, 312, 320, 328, 336, 344, 352, 360, 368, 376, 384, 392, 400, 408, 416, 424, 432, 440, 448, 456, 464, 472, 480, 488, 496, 504, 512] is overridden by config [512, 384, 256, 128, 4, 2, 1, 392, 264, 136, 8, 400, 272, 144, 16, 408, 280, 152, 24, 416, 288, 160, 32, 424, 296, 168, 40, 432, 304, 176, 48, 440, 312, 184, 56, 448, 320, 192, 64, 456, 328, 200, 72, 464, 336, 208, 80, 472, 344, 216, 88, 120, 480, 352, 248, 224, 96, 488, 504, 360, 232, 104, 496, 368, 240, 112, 376]
# WARNING 04-02 15:59:43 [topk_topp_sampler.py:63] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 04-02 15:59:43 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# INFO 04-02 16:00:11 [weight_utils.py:281] Time spent downloading weights for google/gemma-3-4b-it: 27.956070 seconds
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 04-02 16:00:14 [loader.py:447] Loading weights took 2.60 seconds
# INFO 04-02 16:00:15 [gpu_model_runner.py:1186] Model loading took 8.5833 GB and 31.757067 seconds
# INFO 04-02 16:00:15 [gpu_model_runner.py:1456] Encoder cache will be initialized with a budget of 8192 tokens, and profiled with 32 image items of the maximum feature size.
# INFO 04-02 16:00:34 [backends.py:415] Using cache directory: /root/.cache/vllm/torch_compile_cache/4c78114423/rank_0_0 for vLLM's torch.compile
# INFO 04-02 16:00:34 [backends.py:425] Dynamo bytecode transform time: 16.77 s
# INFO 04-02 16:00:41 [backends.py:132] Cache the graph of shape None for later use
# INFO 04-02 16:01:31 [backends.py:144] Compiling a graph for general shape takes 55.21 s
# INFO 04-02 16:02:09 [monitor.py:33] torch.compile takes 71.98 s in total
# INFO 04-02 16:02:10 [kv_cache_utils.py:566] GPU KV cache size: 122,576 tokens
# INFO 04-02 16:02:10 [kv_cache_utils.py:569] Maximum concurrency for 65,536 tokens per request: 1.87x
# INFO 04-02 16:02:50 [gpu_model_runner.py:1534] Graph capturing finished in 40 secs, took 0.56 GiB
# INFO 04-02 16:02:50 [core.py:151] init engine (profile, create kv cache, warmup model) took 155.25 seconds
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How did Real Madrid do in their last La Liga match?                                                             │
# │                                                                                                                 │
# ╰─ VLLMModel - google/gemma-3-4b-it ──────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s, est. speed input: 2323.43 toks/s, output: 80.08 toks/s]
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = web_search(query="Real Madrid last La Liga match result")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Real Madrid vs. Leganes final score: La Liga result, updates, stats as
# ...](https://www.sportingnews.com/us/soccer/news/real-madrid-leganes-score-result-updates-stats-la-liga/8ecf730cfcb
# 9b6c5f6693a0d)
# Real Madrid came through a topsy-turvy game with Leganes to claim a 3-2 victory and put pressure back on Barcelona
# in La Liga's title race.. Kylian Mbappe scored in each half either side of a Jude ...
#
# [Latest results of Real Madrid in Primera División -
# LaLiga](https://www.laliga.com/en-GB/clubs/real-madrid/results)
# Enter and check the latest Real Madrid results in Primera División. All the Real Madrid news on the official LALIGA
# website. ... Next matches. Results. Statistics. Transfers. Latest results of Real Madrid in Primera División
# Results. DATE ... Consigue la Camiseta Oficial del Real Madrid GRATIS ¡Entra en Fans LALIGA, regístrate y participa
# ...
#
# [Real Madrid 3-2 Leganes: Report & Full Match Highlights Mbappe Scores
# ...](https://www.si.com/onsi/soccer/real-madrid/matchday/real-madrid-3-2-leganes-report-full-match-highlights-as-mb
# appe-scores-his-first-ever-free-kick)
# Report and full match highlights from Real Madrid vs Leganes. ... Real Madrid the lead, and score his 21st La Liga
# goal of the season. ⚪️ Kylian Mbappe's panenka penalty means 21 goals in La ...
#
# [Real Madrid vs Leganés: Spanish La Liga stats &
# head-to-head](https://www.bbc.co.uk/sport/football/live/cm2ndndvdgmt)
# FT: Real Madrid 3-2 Leganes. Kylian Mbappe has contributed to goals in his last three games in La Liga (5 goals, 0
# assists). Leganes have lost their last three La Liga games, their last joint ...
#
# [Real Madrid vs. Rayo Vallecano score: La Liga result, stats as Mbappe
# ...](https://www.sportingnews.com/us/soccer/news/real-madrid-rayo-vallecano-score-result-updates-stats-la-liga/fa00
# c963e79843bd83682bc0)
# Real Madrid go second in the La Liga table as first-half goals by Kylian Mbappe and Vinicius Jr secure the three
# points against Rayo Vallecano, but a drab second half will raise questions about ...
#
# [Real Betis vs. Real Madrid final score: La Liga result, stats as Isco
# ...](https://www.sportingnews.com/us/soccer/news/betis-vs-real-madrid-score-result-updates-stats-la-liga/34d83da2f3
# 2feed51313821e)
# Real Betis vs. Real Madrid kick off time This La Liga match kicks off in Seville, Spain at 6:30 p.m. local time.
# Here's how that time translates across some of the major territories:
#
# [RMA vs LEG Highlights, La Liga 2024-25: Mbappe scores brace as Real
# ...](https://sportstar.thehindu.com/football/la-liga/real-madrid-vs-leganes-live-score-updates-la-liga-2024-25-rma-
# v-leg-highlights-goals-mbappe-streaming-info-news/article69390975.ece)
# Real Madrid will be in action for the first time after the international break when it hosts Leganes in the La Liga
# 2024-25 clash at the Santiago Bernabeu on Sunday. Real is currently second in the standings with 60 points from 28
# games, three points behind leader Barcelona, which has played the same number of games.
#
# [Real Madrid vs Barcelona: The results of the last 10 El Clasicos -
# 90min](https://www.90min.com/real-madrid-vs-barcelona-results-last-10-el-clasicos)
# Barcelona 1-2 Real Madrid. La Liga. 5 April 2023. Barcelona 0-4 Real Madrid. Copa del Rey semi-final second leg. 19
# March 2023. Barcelona 2-1 Real Madrid. La Liga. 2 March 2023. Real Madrid 0-1 ...
#
# [Football, Spain: Real Madrid live scores, results,
# fixtures](https://www.flashscore.com/team/real-madrid/WbYZcf7m/)
# Besides Real Madrid scores you can follow 1000+ football competitions from 90+ countries around the world on
# Flashscore.com. Just click on the country name in the left menu and select your competition (league results,
# national cup livescore, other competition). Real Madrid scores service is real-time, updating live.
#
# [Real Madrid 2-1 Rayo (Mar 9, 2025) Game Analysis - ESPN](https://www.espn.com/soccer/report/_/gameId/704926)
# Expert recap and game analysis of the Real Madrid vs. Rayo Vallecano Spanish Laliga game from March 9, 2025 on
# ESPN. ... of their Champions League last-16 tie against rivals Atletico Madrid on ...
#
# Out: None
# [Step 1: Duration 2.01 seconds| Input tokens: 2,263 | Output tokens: 78]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it, est. speed input: 3108.85 toks/s, output: 84.73 toks/s]
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Real Madrid won 3-2")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Real Madrid won 3-2
# [Step 2: Duration 1.20 seconds| Input tokens: 5,932 | Output tokens: 178]
# 'Real Madrid won 3-2'

# %%
print(result)
# Out:
# Real Madrid won 3-2
